# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-8abe972c401b> in <module>()
#       1 get_ipython().magic(u'load_ext autoreload')
#       2 get_ipython().magic(u'autoreload 2')
# ----> 3 get_ipython().magic(u'matplotlib inline')
#
# /Library/Python/2.7/site-packages/IPython/core/interactiveshell.pyc in magic(self, arg_s)
#    2334         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2335         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2336         return self.run_line_magic(magic_name, magic_arg_s)
#    2337
#    2338     #-------------------------------------------------------------------------
#
# /Library/Python/2.7/site-packages/IPython/core/interactiveshell.pyc in run_line_magic(self, magic_name, line)
#    2255                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2256             with self.builtin_trap:
# -> 2257                 result = fn(*args,**kwargs)
#    2258             return result
#    2259
#
# /Library/Python/2.7/site-packages/IPython/core/magics/pylab.pyc in matplotlib(self, line)
#
# /Library/Python/2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /Library/Python/2.7/site-packages/IPython/core/magics/pylab.pyc in matplotlib(self, line)
#      98             print("Available matplotlib backends: %s" % backends_list)
#      99         else:
# --> 100             gui, backend = self.shell.enable_matplotlib(args.gui)
#     101             self._show_matplotlib_backend(args.gui, backend)
#     102
#
# /Library/Python/2.7/site-packages/IPython/core/interactiveshell.pyc in enable_matplotlib(self, gui)
#    3130                 gui, backend = pt.find_gui_and_backend(self.pylab_gui_select)
#    3131
# -> 3132         pt.activate_matplotlib(backend)
#    3133         pt.configure_inline_support(self, backend)
#    3134
#
# /Library/Python/2.7/site-packages/IPython/core/pylabtools.pyc in activate_matplotlib(backend)
#     272     matplotlib.rcParams['backend'] = backend
#     273
# --> 274     import matplotlib.pyplot
#     275     matplotlib.pyplot.switch_backend(backend)
#     276
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/pyplot.py in <module>()
#      27 from matplotlib import docstring
#      28 from matplotlib.backend_bases import FigureCanvasBase
# ---> 29 from matplotlib.figure import Figure, figaspect
#      30 from matplotlib.gridspec import GridSpec
#      31 from matplotlib.image import imread as _imread
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/figure.py in <module>()
#      34 import matplotlib.colorbar as cbar
#      35
# ---> 36 from matplotlib.axes import Axes, SubplotBase, subplot_class_factory
#      37 from matplotlib.blocking_input import BlockingMouseInput, BlockingKeyMouseInput
#      38 from matplotlib.legend import Legend
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/axes.py in <module>()
#      18 import matplotlib.colors as mcolors
#      19 import matplotlib.contour as mcontour
# ---> 20 import matplotlib.dates as _  # <-registers a date unit converter
#      21 from matplotlib import docstring
#      22 import matplotlib.font_manager as font_manager
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/dates.py in <module>()
#     117
#     118
# --> 119 from dateutil.rrule import (rrule, MO, TU, WE, TH, FR, SA, SU, YEARLY,
#     120                             MONTHLY, WEEKLY, DAILY, HOURLY, MINUTELY,
#     121                             SECONDLY)
#
# /Library/Python/2.7/site-packages/dateutil/rrule.py in <module>()
#      17
#      18 from six import advance_iterator, integer_types
# ---> 19 from six.moves import _thread
#      20 import heapq
#      21
#
# ImportError: cannot import name _thread

# %%
from hw1.src.misc import transform_data

from hw2.src.RBM import RBM, get_x, sample

# %%
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# %%
def plot_results(nn, test_x):
    plt.figure(figsize=(16, 5))

    gs = gridspec.GridSpec(2, 5, wspace=0.0, hspace=0.0)
    ax = plt.subplot(gs[:2, :2])
    ax.plot(range(len(nn.scores)), nn.scores);

    for i in range(3):
        test_sample = test_x[np.random.randint(0, 1000)]
        ax = plt.subplot(gs[0, 2 + i]);ax.set_xticks([]);ax.set_yticks([]);
        ax.imshow((test_sample).reshape((28,28)), cmap="gray")
        ax = plt.subplot(gs[1, 2 + i]);ax.set_xticks([]);ax.set_yticks([]);
        ax.imshow(nn.feedforward(test_sample).reshape((28,28)), cmap="gray")

# %% [markdown]
# ## 1. Data preprocessing

# %%
mnist = np.load("./hw1/data/mnist_28x28_train-test-cv.npz")
train_data = transform_data(mnist["train"], norm=False)
cv_data = transform_data(mnist["cv"], norm=False)
test_data = transform_data(mnist["test"], norm=False)

# %%
train_x, train_y = zip(*train_data)
cv_x, cv_y = zip(*cv_data)
test_x, test_y = zip(*test_data)

# %%
encoder_train_data = zip(train_x, train_x)
encoder_cv_data = zip(cv_x, cv_x)

# %% [markdown]
# #### 1.1 Noise Overlay

# %%
def add_noise(x):
    r = np.random.normal(0.0, 0.3, size=28*28)
    r[r < 0] = 0
    return x + r

# %%
noise_train_x = map(add_noise, train_x)
noise_cv_x = map(add_noise, cv_x)
noise_test_x = map(add_noise, test_x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-fd3fe4d0d884> in <module>()
# ----> 1 noise_train_x = map(add_noise, train_x)
#       2 noise_cv_x = map(add_noise, cv_x)
#       3 noise_test_x = map(add_noise, test_x)
#
# NameError: name 'add_noise' is not defined

# %%
noise_encoder_train_data = zip(noise_train_x, train_x)
noise_encoder_cv_data = zip(noise_cv_x, cv_x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8eeafb5e8568> in <module>()
# ----> 1 noise_encoder_train_data = zip(noise_train_x, train_x)
#       2 noise_encoder_cv_data = zip(noise_cv_x, cv_x)
#
# NameError: name 'noise_train_x' is not defined

# %% [markdown]
# ## 2. Load Pre-trained weights

# %%
model_784_1024 = np.load("./hw2/models/rbm_784x1024.npz")
model_1024_512 = np.load("./hw2/models/rbm_1024x512.npz")
model_512_128  = np.load("./hw2/models/rbm_512x128.npz")
model_128_32   = np.load("./hw2/models/rbm_128x32.npz")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-83dbc546b3f3> in <module>()
# ----> 1 model_784_1024 = np.load("./hw2/models/rbm_784x1024.npz")
#       2 model_1024_512 = np.load("./hw2/models/rbm_1024x512.npz")
#       3 model_512_128  = np.load("./hw2/models/rbm_512x128.npz")
#       4 model_128_32   = np.load("./hw2/models/rbm_128x32.npz")
#
# NameError: name 'np' is not defined

# %% [markdown]
# ## 3. Train Denoising Autoencoder

# %%
from hw1.src.NNMiniBatch import NNMiniBatch
from hw1.src.functions.activation_objs import IdentyFunc, TanhFunc, LogisticFunc, ReLuFunc
from hw1.src.functions.cost_objs import QuadraticCost, CrossEntropyCost
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-b9f257972d9b> in <module>()
# ----> 1 from hw1.src.NNMiniBatch import NNMiniBatch
#       2 from hw1.src.functions.activation_objs import IdentyFunc, TanhFunc, LogisticFunc, ReLuFunc
#       3 from hw1.src.functions.cost_objs import QuadraticCost, CrossEntropyCost
#
# /Users/andreyst/Documents/denoising-autoencoder/deep-learning/hw1/src/NNMiniBatch.py in <module>()
#       4 import numpy as np
#       5
# ----> 6 from sklearn.preprocessing import normalize
#       7
#       8 from functions.cost_objs import *
#
# ImportError: No module named sklearn.preprocessing

# %%
params = {
    "sizes": [784, 1024, 512, 128, 32, 128, 512, 1024, 784],
    "activation_functions": [LogisticFunc, LogisticFunc, LogisticFunc, LogisticFunc,
                             LogisticFunc, LogisticFunc, LogisticFunc, LogisticFunc],
    "cost_function": QuadraticCost,
    "epochs": 10,
    "eta": 0.01,
    "l2_rate": 0.3,
    "momentum": 0.4,
    "mini_batch_size": 2000,
    "mode": "batch",
}

nn = NNMiniBatch(**params)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-fed5e5f33676> in <module>()
#       1 params = {
#       2     "sizes": [784, 1024, 512, 128, 32, 128, 512, 1024, 784],
# ----> 3     "activation_functions": [LogisticFunc, LogisticFunc, LogisticFunc, LogisticFunc,
#       4                              LogisticFunc, LogisticFunc, LogisticFunc, LogisticFunc],
#       5     "cost_function": QuadraticCost,
#
# NameError: name 'LogisticFunc' is not defined

# %%
# model_784_1024
nn.w[1] = model_784_1024["w"].T
nn.b[1] = model_784_1024["b"][np.newaxis, :]

# model_1024_512
nn.w[2] = model_1024_512["w"].T
nn.b[2] = model_1024_512["b"][np.newaxis, :]

# model_512_128
nn.w[3] = model_512_128["w"].T
nn.b[3] = model_512_128["b"][np.newaxis, :]

# model_128_32
nn.w[4] = model_128_32["w"].T
nn.b[4] = model_128_32["b"][np.newaxis, :]

# model_128_32
nn.w[5] = model_128_32["w"]
nn.b[5] = model_128_32["a"][np.newaxis, :]

# model_512_128
nn.w[6] = model_512_128["w"]
nn.b[6] = model_512_128["a"][np.newaxis, :]

# model_1024_512
nn.w[7] = model_1024_512["w"]
nn.b[7] = model_1024_512["a"][np.newaxis, :]

# model_784_1024
nn.w[8] = model_784_1024["w"]
nn.b[8] = model_784_1024["a"][np.newaxis, :]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-08afa25dc8be> in <module>()
#       1 # model_784_1024
# ----> 2 nn.w[1] = model_784_1024["w"].T
#       3 nn.b[1] = model_784_1024["b"][np.newaxis, :]
#       4
#       5 # model_1024_512
#
# NameError: name 'model_784_1024' is not defined

# %%
nn.sgd(noise_encoder_train_data, noise_encoder_cv_data);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-9d644c3e0161> in <module>()
# ----> 1 nn.sgd(noise_encoder_train_data, noise_encoder_cv_data);
#
# NameError: name 'nn' is not defined

# %% [markdown]
# **Score = 14.0**

# %%
plot_results(nn, noise_test_x)

# %%
nn.feedforward(np.array(test_x));

# %% [markdown]
# ## 4. 2D projection

# %%
from sklearn import manifold

tsne = manifold.TSNE(n_components=2, init='pca', random_state=0, verbose=2)
X_tsne = tsne.fit_transform(nn.z[4])
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 0.000613
# [t-SNE] Iteration 10: error = 22.7101042, gradient norm = 0.0051762
# [t-SNE] Iteration 20: error = 21.9120468, gradient norm = 0.0108806
# [t-SNE] Iteration 30: error = 21.5779900, gradient norm = 0.0144631
# [t-SNE] Iteration 40: error = 21.4409262, gradient norm = 0.0173406
# [t-SNE] Iteration 50: error = 21.4031182, gradient norm = 0.0196396
# [t-SNE] Iteration 60: error = 20.3180974, gradient norm = 0.0095971
# [t-SNE] Iteration 70: error = 19.5661047, gradient norm = 0.0076459
# [t-SNE] Iteration 80: error = 19.2812212, gradient norm = 0.0147998
# [t-SNE] Iteration 90: error = 19.1996630, gradient norm = 0.0200561
# [t-SNE] Iteration 100: error = 19.2044417, gradient norm = 0.0232415
# [t-SNE] Error after 100 iterations with early exaggeration: 19.204442
# [t-SNE] Iteration 110: error = 3.1624689, gradient norm = 0.0035923
# [t-SNE] Iteration 120: error = 3.0035871, gradient norm = 0.0020697
# [t-SNE] Iteration 130: error = 2.9249792, gradient norm = 0.0018558
# [t-SNE] Iteration 140: error = 2.8834413, gradient norm = 0.0017726
# [t-SNE] Iteration 150: error = 2.8603974, gradient norm = 0.0017317
# [t-SNE] Iteration 160: error = 2.8471966, gradient norm = 0.0017091
# [t-SNE] Iteration 170: error = 2.8394925, gradient norm = 0.0016960
# [t-SNE] Iteration 180: error = 2.8349484, gradient norm = 0.0016883
# [t-SNE] Iteration 190: error = 2.8322517, gradient norm = 0.0016838
# [t-SNE] Iteration 200: error = 2.8306456, gradient norm = 0.0016811
# [t-SNE] Iteration 210: error = 2.8296869, gradient norm = 0.0016795
# [t-SNE] Iteration 220: error = 2.8291140, gradient norm = 0.0016785
# [t-SNE] Iteration 230: error = 2.8287714, gradient norm = 0.0016779
# [t-SNE] Iteration 240: error = 2.8285664, gradient norm = 0.0016776
# [t-SNE] Iteration 250: error = 2.8284437, gradient norm = 0.0016774
# [t-SNE] Iteration 260: error = 2.8283702, gradient norm = 0.0016773
# [t-SNE] Iteration 270: error = 2.8283262, gradient norm = 0.0016772
# [t-SNE] Iteration 280: error = 2.8282999, gradient norm = 0.0016772
# [t-SNE] Iteration 290: error = 2.8282842, gradient norm = 0.0016771
# [t-SNE] Iteration 300: error = 2.8282747, gradient norm = 0.0016771
# [t-SNE] Iteration 310: error = 2.8282691, gradient norm = 0.0016771
# [t-SNE] Iteration 320: error = 2.8282657, gradient norm = 0.0016771
# [t-SNE] Iteration 330: error = 2.8282637, gradient norm = 0.0016771
# [t-SNE] Iteration 340: error difference 0.000000. Finished.
# [t-SNE] Error after 340 iterations: 2.828262

# %%
y = np.argmax(test_y, axis=1)

# %%
plt.figure(figsize=(10, 50))

for i in range(10):
    plt.scatter(X_tsne[:, 0][y == i], X_tsne[:, 1][y == i], c=colors[i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d6d84cb23b90> in <module>()
# ----> 1 plt.figure(figsize=(10, 50))
#       2
#       3 for i in range(10):
#       4     plt.scatter(X_tsne[:, 0][y == i], X_tsne[:, 1][y == i], c=colors[i])
#
# NameError: name 'plt' is not defined
